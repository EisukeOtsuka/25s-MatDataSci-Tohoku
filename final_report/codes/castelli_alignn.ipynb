# %%
# ❶ 依存ライブラリを明示的に固定＆インストール（互換性を保つため）
# !pip install numpy==1.26.4
# !pip install torch==2.2.1 torchvision==0.17.1 torchaudio==2.2.1
# !pip install matminer seaborn
# !pip install git+https://github.com/usnistgov/alignn.git
# Out:
# Requirement already satisfied: numpy==1.26.4 in /usr/local/lib/python3.11/dist-packages (1.26.4)
# Requirement already satisfied: torch==2.2.1 in /usr/local/lib/python3.11/dist-packages (2.2.1)
# Collecting torchvision==0.17.1
#   Downloading torchvision-0.17.1-cp311-cp311-manylinux1_x86_64.whl.metadata (6.6 kB)
# Collecting torchaudio==2.2.1
#   Downloading torchaudio-2.2.1-cp311-cp311-manylinux1_x86_64.whl.metadata (6.4 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch==2.2.1) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch==2.2.1) (4.13.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from torch==2.2.1) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch==2.2.1) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch==2.2.1) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch==2.2.1) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch==2.2.1) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch==2.2.1) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch==2.2.1) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.11/dist-packages (from torch==2.2.1) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.11/dist-packages (from torch==2.2.1) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.11/dist-packages (from torch==2.2.1) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.11/dist-packages (from torch==2.2.1) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.11/dist-packages (from torch==2.2.1) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.11/dist-packages (from torch==2.2.1) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.11/dist-packages (from torch==2.2.1) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch==2.2.1) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.11/dist-packages (from torch==2.2.1) (2.2.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision==0.17.1) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision==0.17.1) (11.2.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.2.1) (12.5.82)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch==2.2.1) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->torch==2.2.1) (1.3.0)
# Downloading torchvision-0.17.1-cp311-cp311-manylinux1_x86_64.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 66.9 MB/s eta 0:00:00
# Downloading torchaudio-2.2.1-cp311-cp311-manylinux1_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 69.1 MB/s eta 0:00:00
# Installing collected packages: torchvision, torchaudio
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.21.0+cu124
#     Uninstalling torchvision-0.21.0+cu124:
#       Successfully uninstalled torchvision-0.21.0+cu124
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 2.6.0+cu124
#     Uninstalling torchaudio-2.6.0+cu124:
#       Successfully uninstalled torchaudio-2.6.0+cu124
# Successfully installed torchaudio-2.2.1 torchvision-0.17.1
# Requirement already satisfied: matminer in /usr/local/lib/python3.11/dist-packages (0.9.3)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.11/dist-packages (0.13.2)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.11/dist-packages (from matminer) (1.26.4)
# Requirement already satisfied: requests~=2.31 in /usr/local/lib/python3.11/dist-packages (from matminer) (2.32.3)
# Requirement already satisfied: pandas<3,>=1.5 in /usr/local/lib/python3.11/dist-packages (from matminer) (2.2.2)
# Requirement already satisfied: tqdm~=4.66 in /usr/local/lib/python3.11/dist-packages (from matminer) (4.67.1)
# Requirement already satisfied: pymongo~=4.5 in /usr/local/lib/python3.11/dist-packages (from matminer) (4.13.0)
# Requirement already satisfied: scikit-learn~=1.3 in /usr/local/lib/python3.11/dist-packages (from matminer) (1.6.1)
# Requirement already satisfied: sympy~=1.11 in /usr/local/lib/python3.11/dist-packages (from matminer) (1.13.1)
# Requirement already satisfied: monty>=2023 in /usr/local/lib/python3.11/dist-packages (from matminer) (2025.3.3)
# Requirement already satisfied: pymatgen>=2023 in /usr/local/lib/python3.11/dist-packages (from matminer) (2025.5.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /usr/local/lib/python3.11/dist-packages (from seaborn) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: ruamel.yaml in /usr/local/lib/python3.11/dist-packages (from monty>=2023->matminer) (0.18.10)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=1.5->matminer) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=1.5->matminer) (2025.2)
# Requirement already satisfied: joblib>=1 in /usr/local/lib/python3.11/dist-packages (from pymatgen>=2023->matminer) (1.5.0)
# Requirement already satisfied: networkx>=2.7 in /usr/local/lib/python3.11/dist-packages (from pymatgen>=2023->matminer) (3.4.2)
# Requirement already satisfied: palettable>=3.3.3 in /usr/local/lib/python3.11/dist-packages (from pymatgen>=2023->matminer) (3.3.3)
# Requirement already satisfied: plotly>=5.0.0 in /usr/local/lib/python3.11/dist-packages (from pymatgen>=2023->matminer) (5.24.1)
# Requirement already satisfied: bibtexparser>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from pymatgen>=2023->matminer) (1.4.3)
# Requirement already satisfied: scipy>=1.13.0 in /usr/local/lib/python3.11/dist-packages (from pymatgen>=2023->matminer) (1.15.3)
# Requirement already satisfied: spglib>=2.5 in /usr/local/lib/python3.11/dist-packages (from pymatgen>=2023->matminer) (2.6.0)
# Requirement already satisfied: tabulate>=0.9 in /usr/local/lib/python3.11/dist-packages (from pymatgen>=2023->matminer) (0.9.0)
# Requirement already satisfied: uncertainties>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from pymatgen>=2023->matminer) (3.2.3)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from pymongo~=4.5->matminer) (2.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests~=2.31->matminer) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests~=2.31->matminer) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests~=2.31->matminer) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests~=2.31->matminer) (2025.4.26)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn~=1.3->matminer) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy~=1.11->matminer) (1.3.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly>=5.0.0->pymatgen>=2023->matminer) (9.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /usr/local/lib/python3.11/dist-packages (from ruamel.yaml->monty>=2023->matminer) (0.2.12)
# Requirement already satisfied: typing-extensions>=4.9.0 in /usr/local/lib/python3.11/dist-packages (from spglib>=2.5->pymatgen>=2023->matminer) (4.13.2)
# Collecting git+https://github.com/usnistgov/alignn.git
#   Cloning https://github.com/usnistgov/alignn.git to /tmp/pip-req-build-58ky5jle
#   Running command git clone --filter=blob:none --quiet https://github.com/usnistgov/alignn.git /tmp/pip-req-build-58ky5jle
#   Resolved https://github.com/usnistgov/alignn.git to commit 408bb6e996006dc4441ea48d4189047742dad637
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy<2.0 in /usr/local/lib/python3.11/dist-packages (from alignn==2025.4.1) (1.26.4)
# Requirement already satisfied: scipy>=1.6.1 in /usr/local/lib/python3.11/dist-packages (from alignn==2025.4.1) (1.15.3)
# Requirement already satisfied: jarvis-tools>=2021.07.19 in /usr/local/lib/python3.11/dist-packages (from alignn==2025.4.1) (2024.10.30)
# Requirement already satisfied: torch<=2.2.1 in /usr/local/lib/python3.11/dist-packages (from alignn==2025.4.1) (2.2.1)
# Requirement already satisfied: mpmath<=1.3.0 in /usr/local/lib/python3.11/dist-packages (from alignn==2025.4.1) (1.3.0)
# Requirement already satisfied: dgl<=1.1.1 in /usr/local/lib/python3.11/dist-packages (from alignn==2025.4.1) (1.1.1)
# Requirement already satisfied: spglib>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from alignn==2025.4.1) (2.6.0)
# Requirement already satisfied: scikit-learn>=0.22.2 in /usr/local/lib/python3.11/dist-packages (from alignn==2025.4.1) (1.6.1)
# Requirement already satisfied: matplotlib>=3.4.1 in /usr/local/lib/python3.11/dist-packages (from alignn==2025.4.1) (3.10.0)
# Requirement already satisfied: tqdm>=4.60.0 in /usr/local/lib/python3.11/dist-packages (from alignn==2025.4.1) (4.67.1)
# Requirement already satisfied: pandas>=1.2.3 in /usr/local/lib/python3.11/dist-packages (from alignn==2025.4.1) (2.2.2)
# Requirement already satisfied: pydantic>=1.8.1 in /usr/local/lib/python3.11/dist-packages (from alignn==2025.4.1) (2.11.4)
# Requirement already satisfied: pydantic-settings in /usr/local/lib/python3.11/dist-packages (from alignn==2025.4.1) (2.9.1)
# Requirement already satisfied: flake8>=3.9.1 in /usr/local/lib/python3.11/dist-packages (from alignn==2025.4.1) (7.2.0)
# Requirement already satisfied: pycodestyle>=2.7.0 in /usr/local/lib/python3.11/dist-packages (from alignn==2025.4.1) (2.13.0)
# Requirement already satisfied: pydocstyle>=6.0.0 in /usr/local/lib/python3.11/dist-packages (from alignn==2025.4.1) (6.3.0)
# Requirement already satisfied: pyparsing<3,>=2.2.1 in /usr/local/lib/python3.11/dist-packages (from alignn==2025.4.1) (2.4.7)
# Requirement already satisfied: ase in /usr/local/lib/python3.11/dist-packages (from alignn==2025.4.1) (3.25.0)
# Requirement already satisfied: lmdb in /usr/local/lib/python3.11/dist-packages (from alignn==2025.4.1) (1.6.2)
# Requirement already satisfied: networkx>=2.1 in /usr/local/lib/python3.11/dist-packages (from dgl<=1.1.1->alignn==2025.4.1) (3.4.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from dgl<=1.1.1->alignn==2025.4.1) (2.32.3)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.11/dist-packages (from dgl<=1.1.1->alignn==2025.4.1) (5.9.5)
# Requirement already satisfied: mccabe<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from flake8>=3.9.1->alignn==2025.4.1) (0.7.0)
# Requirement already satisfied: pyflakes<3.4.0,>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from flake8>=3.9.1->alignn==2025.4.1) (3.3.2)
# Requirement already satisfied: joblib>=0.14.1 in /usr/local/lib/python3.11/dist-packages (from jarvis-tools>=2021.07.19->alignn==2025.4.1) (1.5.0)
# Requirement already satisfied: toolz>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from jarvis-tools>=2021.07.19->alignn==2025.4.1) (0.12.1)
# Requirement already satisfied: xmltodict>=0.11.0 in /usr/local/lib/python3.11/dist-packages (from jarvis-tools>=2021.07.19->alignn==2025.4.1) (0.14.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.4.1->alignn==2025.4.1) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.4.1->alignn==2025.4.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.4.1->alignn==2025.4.1) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.4.1->alignn==2025.4.1) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.4.1->alignn==2025.4.1) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.4.1->alignn==2025.4.1) (11.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.4.1->alignn==2025.4.1) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2.3->alignn==2025.4.1) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2.3->alignn==2025.4.1) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=1.8.1->alignn==2025.4.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=1.8.1->alignn==2025.4.1) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=1.8.1->alignn==2025.4.1) (4.13.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=1.8.1->alignn==2025.4.1) (0.4.0)
# Requirement already satisfied: snowballstemmer>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from pydocstyle>=6.0.0->alignn==2025.4.1) (3.0.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.22.2->alignn==2025.4.1) (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch<=2.2.1->alignn==2025.4.1) (3.18.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from torch<=2.2.1->alignn==2025.4.1) (1.13.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<=2.2.1->alignn==2025.4.1) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch<=2.2.1->alignn==2025.4.1) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch<=2.2.1->alignn==2025.4.1) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch<=2.2.1->alignn==2025.4.1) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch<=2.2.1->alignn==2025.4.1) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.11/dist-packages (from torch<=2.2.1->alignn==2025.4.1) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.11/dist-packages (from torch<=2.2.1->alignn==2025.4.1) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.11/dist-packages (from torch<=2.2.1->alignn==2025.4.1) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.11/dist-packages (from torch<=2.2.1->alignn==2025.4.1) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.11/dist-packages (from torch<=2.2.1->alignn==2025.4.1) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.11/dist-packages (from torch<=2.2.1->alignn==2025.4.1) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.11/dist-packages (from torch<=2.2.1->alignn==2025.4.1) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch<=2.2.1->alignn==2025.4.1) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.11/dist-packages (from torch<=2.2.1->alignn==2025.4.1) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch<=2.2.1->alignn==2025.4.1) (12.5.82)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from pydantic-settings->alignn==2025.4.1) (1.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.4.1->alignn==2025.4.1) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->dgl<=1.1.1->alignn==2025.4.1) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->dgl<=1.1.1->alignn==2025.4.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->dgl<=1.1.1->alignn==2025.4.1) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->dgl<=1.1.1->alignn==2025.4.1) (2025.4.26)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch<=2.2.1->alignn==2025.4.1) (3.0.2)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# Set universal theme for figures
plt.style.use('seaborn-v0_8')
# Configure plot settings
plt.rcParams['figure.figsize'] = (6, 4.5)
plt.rcParams['figure.dpi'] = 300
plt.rcParams['axes.grid'] = True
# Set numerical precision
np.set_printoptions(precision=5)

# %%
import gzip
import json
import os
from tqdm import tqdm
from pymatgen.core import Structure

# ✅ JSON Lines形式で読み込み
with gzip.open("castelli_perovskites.json.gz", "rt") as f:
    data = [json.loads(line) for line in f if line.strip()]

# gapありデータ抽出
valid_entries = [d for d in data if d.get("gap gllbsc") is not None]

# ALIGNN形式データ構築
os.makedirs("data", exist_ok=True)
alignn_data = []
for i, entry in enumerate(tqdm(valid_entries[:500])):  # ←件数は調整可能
    try:
        struct = Structure.from_dict(entry["structure"])
        gap = entry["gap gllbsc"]
        poscar_path = f"data/{i}.poscar"
        struct.to(fmt="poscar", filename=poscar_path)
        alignn_data.append({"id": str(i), "target": gap, "poscar": poscar_path})
    except Exception as e:
        print(f"Error at {i}: {e}")

# 保存
with open("atomistic.json", "w") as f:
    json.dump(alignn_data, f, indent=2)
# Out:
# 0it [00:00, ?it/s]

# %%
from pymatgen.core import Structure
import os
from tqdm import tqdm
import json

# バンドギャップが存在するデータのみ対象
df = df[df["gap gllbsc"].notnull()].reset_index(drop=True)

# 出力ディレクトリ作成
os.makedirs("data", exist_ok=True)

# ALIGNN用の入力リスト
alignn_data = []

# 500件程度に限定（任意で変更可）
for i, row in tqdm(df[:500].iterrows(), total=500):
    try:
        struct = Structure.from_dict(row["structure"])
        gap = row["gap gllbsc"]
        poscar_path = f"data/{i}.poscar"
        struct.to(fmt="poscar", filename=poscar_path)
        alignn_data.append({
            "id": str(i),
            "target": gap,
            "poscar": poscar_path
        })
    except Exception as e:
        print(f"Error in row {i}: {e}")

# ラベルファイル保存
with open("atomistic.json", "w") as f:
    json.dump(alignn_data, f, indent=2)
# Out:
# 100%|██████████| 500/500 [00:01<00:00, 278.37it/s]

# %%
from alignn.train_config import TrainingConfig
import json

cfg = TrainingConfig(
    dataset="atomistic.json",
    output_dir="alignn_out",
    batch_size=32,
    epochs=20,
    learning_rate=0.001,
    task="regression",
    prediction_type="atomistic"  # ← POSCAR単位の回帰
)

# 設定ファイル保存
with open("config.json", "w") as f:
    json.dump(cfg.as_dict(), f, indent=2)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-2ff42b06d100> in <cell line: 0>()
# ----> 1 from alignn.train_config import TrainingConfig
#       2 import json
#       3
#       4 cfg = TrainingConfig(
#       5     dataset="atomistic.json",
#
# ModuleNotFoundError: No module named 'alignn.train_config'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install git+https://github.com/usnistgov/alignn.git
# Out:
# Collecting git+https://github.com/usnistgov/alignn.git
#   Cloning https://github.com/usnistgov/alignn.git to /tmp/pip-req-build-2i9_9zk7
#   Running command git clone --filter=blob:none --quiet https://github.com/usnistgov/alignn.git /tmp/pip-req-build-2i9_9zk7
#   Resolved https://github.com/usnistgov/alignn.git to commit 408bb6e996006dc4441ea48d4189047742dad637
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy<2.0 in /usr/local/lib/python3.11/dist-packages (from alignn==2025.4.1) (1.26.4)
# Requirement already satisfied: scipy>=1.6.1 in /usr/local/lib/python3.11/dist-packages (from alignn==2025.4.1) (1.15.3)
# Requirement already satisfied: jarvis-tools>=2021.07.19 in /usr/local/lib/python3.11/dist-packages (from alignn==2025.4.1) (2024.10.30)
# Requirement already satisfied: torch<=2.2.1 in /usr/local/lib/python3.11/dist-packages (from alignn==2025.4.1) (2.2.1)
# Requirement already satisfied: mpmath<=1.3.0 in /usr/local/lib/python3.11/dist-packages (from alignn==2025.4.1) (1.3.0)
# Requirement already satisfied: dgl<=1.1.1 in /usr/local/lib/python3.11/dist-packages (from alignn==2025.4.1) (1.1.1)
# Requirement already satisfied: spglib>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from alignn==2025.4.1) (2.6.0)
# Requirement already satisfied: scikit-learn>=0.22.2 in /usr/local/lib/python3.11/dist-packages (from alignn==2025.4.1) (1.6.1)
# Requirement already satisfied: matplotlib>=3.4.1 in /usr/local/lib/python3.11/dist-packages (from alignn==2025.4.1) (3.10.0)
# Requirement already satisfied: tqdm>=4.60.0 in /usr/local/lib/python3.11/dist-packages (from alignn==2025.4.1) (4.67.1)
# Requirement already satisfied: pandas>=1.2.3 in /usr/local/lib/python3.11/dist-packages (from alignn==2025.4.1) (2.2.2)
# Requirement already satisfied: pydantic>=1.8.1 in /usr/local/lib/python3.11/dist-packages (from alignn==2025.4.1) (2.11.4)
# Requirement already satisfied: pydantic-settings in /usr/local/lib/python3.11/dist-packages (from alignn==2025.4.1) (2.9.1)
# Requirement already satisfied: flake8>=3.9.1 in /usr/local/lib/python3.11/dist-packages (from alignn==2025.4.1) (7.2.0)
# Requirement already satisfied: pycodestyle>=2.7.0 in /usr/local/lib/python3.11/dist-packages (from alignn==2025.4.1) (2.13.0)
# Requirement already satisfied: pydocstyle>=6.0.0 in /usr/local/lib/python3.11/dist-packages (from alignn==2025.4.1) (6.3.0)
# Requirement already satisfied: pyparsing<3,>=2.2.1 in /usr/local/lib/python3.11/dist-packages (from alignn==2025.4.1) (2.4.7)
# Requirement already satisfied: ase in /usr/local/lib/python3.11/dist-packages (from alignn==2025.4.1) (3.25.0)
# Requirement already satisfied: lmdb in /usr/local/lib/python3.11/dist-packages (from alignn==2025.4.1) (1.6.2)
# Requirement already satisfied: networkx>=2.1 in /usr/local/lib/python3.11/dist-packages (from dgl<=1.1.1->alignn==2025.4.1) (3.4.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from dgl<=1.1.1->alignn==2025.4.1) (2.32.3)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.11/dist-packages (from dgl<=1.1.1->alignn==2025.4.1) (5.9.5)
# Requirement already satisfied: mccabe<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from flake8>=3.9.1->alignn==2025.4.1) (0.7.0)
# Requirement already satisfied: pyflakes<3.4.0,>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from flake8>=3.9.1->alignn==2025.4.1) (3.3.2)
# Requirement already satisfied: joblib>=0.14.1 in /usr/local/lib/python3.11/dist-packages (from jarvis-tools>=2021.07.19->alignn==2025.4.1) (1.5.0)
# Requirement already satisfied: toolz>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from jarvis-tools>=2021.07.19->alignn==2025.4.1) (0.12.1)
# Requirement already satisfied: xmltodict>=0.11.0 in /usr/local/lib/python3.11/dist-packages (from jarvis-tools>=2021.07.19->alignn==2025.4.1) (0.14.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.4.1->alignn==2025.4.1) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.4.1->alignn==2025.4.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.4.1->alignn==2025.4.1) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.4.1->alignn==2025.4.1) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.4.1->alignn==2025.4.1) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.4.1->alignn==2025.4.1) (11.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.4.1->alignn==2025.4.1) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2.3->alignn==2025.4.1) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2.3->alignn==2025.4.1) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=1.8.1->alignn==2025.4.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=1.8.1->alignn==2025.4.1) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=1.8.1->alignn==2025.4.1) (4.13.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=1.8.1->alignn==2025.4.1) (0.4.0)
# Requirement already satisfied: snowballstemmer>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from pydocstyle>=6.0.0->alignn==2025.4.1) (3.0.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.22.2->alignn==2025.4.1) (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch<=2.2.1->alignn==2025.4.1) (3.18.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from torch<=2.2.1->alignn==2025.4.1) (1.13.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<=2.2.1->alignn==2025.4.1) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch<=2.2.1->alignn==2025.4.1) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch<=2.2.1->alignn==2025.4.1) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch<=2.2.1->alignn==2025.4.1) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch<=2.2.1->alignn==2025.4.1) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.11/dist-packages (from torch<=2.2.1->alignn==2025.4.1) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.11/dist-packages (from torch<=2.2.1->alignn==2025.4.1) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.11/dist-packages (from torch<=2.2.1->alignn==2025.4.1) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.11/dist-packages (from torch<=2.2.1->alignn==2025.4.1) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.11/dist-packages (from torch<=2.2.1->alignn==2025.4.1) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.11/dist-packages (from torch<=2.2.1->alignn==2025.4.1) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.11/dist-packages (from torch<=2.2.1->alignn==2025.4.1) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch<=2.2.1->alignn==2025.4.1) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.11/dist-packages (from torch<=2.2.1->alignn==2025.4.1) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch<=2.2.1->alignn==2025.4.1) (12.5.82)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from pydantic-settings->alignn==2025.4.1) (1.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.4.1->alignn==2025.4.1) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->dgl<=1.1.1->alignn==2025.4.1) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->dgl<=1.1.1->alignn==2025.4.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->dgl<=1.1.1->alignn==2025.4.1) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->dgl<=1.1.1->alignn==2025.4.1) (2025.4.26)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch<=2.2.1->alignn==2025.4.1) (3.0.2)

# %%
# Step 1: 学習設定ファイル
from alignn.train_config import TrainingConfig
import json

cfg = TrainingConfig(
    dataset="atomistic.json",
    output_dir="alignn_out",
    batch_size=32,
    epochs=20,
    learning_rate=0.001,
    task="regression",
    prediction_type="atomistic"
)

with open("config.json", "w") as f:
    json.dump(cfg.as_dict(), f, indent=2)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-11-2337aca44c54> in <cell line: 0>()
#       1 # Step 1: 学習設定ファイル
# ----> 2 from alignn.train_config import TrainingConfig
#       3 import json
#       4
#       5 cfg = TrainingConfig(
#
# ModuleNotFoundError: No module named 'alignn.train_config'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# 最新のALIGNNをGitHubからインストール
# !pip install git+https://github.com/usnistgov/alignn.git

# その他必要ライブラリ
# !pip install matminer pymatgen seaborn tqdm
# Out:
# Collecting git+https://github.com/usnistgov/alignn.git
#   Cloning https://github.com/usnistgov/alignn.git to /tmp/pip-req-build-ycampbfy
#   Running command git clone --filter=blob:none --quiet https://github.com/usnistgov/alignn.git /tmp/pip-req-build-ycampbfy
#   Resolved https://github.com/usnistgov/alignn.git to commit 408bb6e996006dc4441ea48d4189047742dad637
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy<2.0 in /usr/local/lib/python3.11/dist-packages (from alignn==2025.4.1) (1.26.4)
# Requirement already satisfied: scipy>=1.6.1 in /usr/local/lib/python3.11/dist-packages (from alignn==2025.4.1) (1.15.3)
# Requirement already satisfied: jarvis-tools>=2021.07.19 in /usr/local/lib/python3.11/dist-packages (from alignn==2025.4.1) (2024.10.30)
# Requirement already satisfied: torch<=2.2.1 in /usr/local/lib/python3.11/dist-packages (from alignn==2025.4.1) (2.2.1)
# Requirement already satisfied: mpmath<=1.3.0 in /usr/local/lib/python3.11/dist-packages (from alignn==2025.4.1) (1.3.0)
# Requirement already satisfied: dgl<=1.1.1 in /usr/local/lib/python3.11/dist-packages (from alignn==2025.4.1) (1.1.1)
# Requirement already satisfied: spglib>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from alignn==2025.4.1) (2.6.0)
# Requirement already satisfied: scikit-learn>=0.22.2 in /usr/local/lib/python3.11/dist-packages (from alignn==2025.4.1) (1.6.1)
# Requirement already satisfied: matplotlib>=3.4.1 in /usr/local/lib/python3.11/dist-packages (from alignn==2025.4.1) (3.10.0)
# Requirement already satisfied: tqdm>=4.60.0 in /usr/local/lib/python3.11/dist-packages (from alignn==2025.4.1) (4.67.1)
# Requirement already satisfied: pandas>=1.2.3 in /usr/local/lib/python3.11/dist-packages (from alignn==2025.4.1) (2.2.2)
# Requirement already satisfied: pydantic>=1.8.1 in /usr/local/lib/python3.11/dist-packages (from alignn==2025.4.1) (2.11.4)
# Requirement already satisfied: pydantic-settings in /usr/local/lib/python3.11/dist-packages (from alignn==2025.4.1) (2.9.1)
# Requirement already satisfied: flake8>=3.9.1 in /usr/local/lib/python3.11/dist-packages (from alignn==2025.4.1) (7.2.0)
# Requirement already satisfied: pycodestyle>=2.7.0 in /usr/local/lib/python3.11/dist-packages (from alignn==2025.4.1) (2.13.0)
# Requirement already satisfied: pydocstyle>=6.0.0 in /usr/local/lib/python3.11/dist-packages (from alignn==2025.4.1) (6.3.0)
# Requirement already satisfied: pyparsing<3,>=2.2.1 in /usr/local/lib/python3.11/dist-packages (from alignn==2025.4.1) (2.4.7)
# Requirement already satisfied: ase in /usr/local/lib/python3.11/dist-packages (from alignn==2025.4.1) (3.25.0)
# Requirement already satisfied: lmdb in /usr/local/lib/python3.11/dist-packages (from alignn==2025.4.1) (1.6.2)
# Requirement already satisfied: networkx>=2.1 in /usr/local/lib/python3.11/dist-packages (from dgl<=1.1.1->alignn==2025.4.1) (3.4.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from dgl<=1.1.1->alignn==2025.4.1) (2.32.3)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.11/dist-packages (from dgl<=1.1.1->alignn==2025.4.1) (5.9.5)
# Requirement already satisfied: mccabe<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from flake8>=3.9.1->alignn==2025.4.1) (0.7.0)
# Requirement already satisfied: pyflakes<3.4.0,>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from flake8>=3.9.1->alignn==2025.4.1) (3.3.2)
# Requirement already satisfied: joblib>=0.14.1 in /usr/local/lib/python3.11/dist-packages (from jarvis-tools>=2021.07.19->alignn==2025.4.1) (1.5.0)
# Requirement already satisfied: toolz>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from jarvis-tools>=2021.07.19->alignn==2025.4.1) (0.12.1)
# Requirement already satisfied: xmltodict>=0.11.0 in /usr/local/lib/python3.11/dist-packages (from jarvis-tools>=2021.07.19->alignn==2025.4.1) (0.14.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.4.1->alignn==2025.4.1) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.4.1->alignn==2025.4.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.4.1->alignn==2025.4.1) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.4.1->alignn==2025.4.1) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.4.1->alignn==2025.4.1) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.4.1->alignn==2025.4.1) (11.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.4.1->alignn==2025.4.1) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2.3->alignn==2025.4.1) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2.3->alignn==2025.4.1) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=1.8.1->alignn==2025.4.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=1.8.1->alignn==2025.4.1) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=1.8.1->alignn==2025.4.1) (4.13.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=1.8.1->alignn==2025.4.1) (0.4.0)
# Requirement already satisfied: snowballstemmer>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from pydocstyle>=6.0.0->alignn==2025.4.1) (3.0.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.22.2->alignn==2025.4.1) (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch<=2.2.1->alignn==2025.4.1) (3.18.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from torch<=2.2.1->alignn==2025.4.1) (1.13.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<=2.2.1->alignn==2025.4.1) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch<=2.2.1->alignn==2025.4.1) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch<=2.2.1->alignn==2025.4.1) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch<=2.2.1->alignn==2025.4.1) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch<=2.2.1->alignn==2025.4.1) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.11/dist-packages (from torch<=2.2.1->alignn==2025.4.1) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.11/dist-packages (from torch<=2.2.1->alignn==2025.4.1) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.11/dist-packages (from torch<=2.2.1->alignn==2025.4.1) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.11/dist-packages (from torch<=2.2.1->alignn==2025.4.1) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.11/dist-packages (from torch<=2.2.1->alignn==2025.4.1) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.11/dist-packages (from torch<=2.2.1->alignn==2025.4.1) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.11/dist-packages (from torch<=2.2.1->alignn==2025.4.1) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch<=2.2.1->alignn==2025.4.1) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.11/dist-packages (from torch<=2.2.1->alignn==2025.4.1) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch<=2.2.1->alignn==2025.4.1) (12.5.82)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from pydantic-settings->alignn==2025.4.1) (1.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.4.1->alignn==2025.4.1) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->dgl<=1.1.1->alignn==2025.4.1) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->dgl<=1.1.1->alignn==2025.4.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->dgl<=1.1.1->alignn==2025.4.1) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->dgl<=1.1.1->alignn==2025.4.1) (2025.4.26)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch<=2.2.1->alignn==2025.4.1) (3.0.2)
# Requirement already satisfied: matminer in /usr/local/lib/python3.11/dist-packages (0.9.3)
# Requirement already satisfied: pymatgen in /usr/local/lib/python3.11/dist-packages (2025.5.2)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.11/dist-packages (0.13.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (4.67.1)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.11/dist-packages (from matminer) (1.26.4)
# Requirement already satisfied: requests~=2.31 in /usr/local/lib/python3.11/dist-packages (from matminer) (2.32.3)
# Requirement already satisfied: pandas<3,>=1.5 in /usr/local/lib/python3.11/dist-packages (from matminer) (2.2.2)
# Requirement already satisfied: pymongo~=4.5 in /usr/local/lib/python3.11/dist-packages (from matminer) (4.13.0)
# Requirement already satisfied: scikit-learn~=1.3 in /usr/local/lib/python3.11/dist-packages (from matminer) (1.6.1)
# Requirement already satisfied: sympy~=1.11 in /usr/local/lib/python3.11/dist-packages (from matminer) (1.13.1)
# Requirement already satisfied: monty>=2023 in /usr/local/lib/python3.11/dist-packages (from matminer) (2025.3.3)
# Requirement already satisfied: joblib>=1 in /usr/local/lib/python3.11/dist-packages (from pymatgen) (1.5.0)
# Requirement already satisfied: matplotlib>=3.8 in /usr/local/lib/python3.11/dist-packages (from pymatgen) (3.10.0)
# Requirement already satisfied: networkx>=2.7 in /usr/local/lib/python3.11/dist-packages (from pymatgen) (3.4.2)
# Requirement already satisfied: palettable>=3.3.3 in /usr/local/lib/python3.11/dist-packages (from pymatgen) (3.3.3)
# Requirement already satisfied: plotly>=5.0.0 in /usr/local/lib/python3.11/dist-packages (from pymatgen) (5.24.1)
# Requirement already satisfied: bibtexparser>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from pymatgen) (1.4.3)
# Requirement already satisfied: ruamel.yaml>=0.17.0 in /usr/local/lib/python3.11/dist-packages (from pymatgen) (0.18.10)
# Requirement already satisfied: scipy>=1.13.0 in /usr/local/lib/python3.11/dist-packages (from pymatgen) (1.15.3)
# Requirement already satisfied: spglib>=2.5 in /usr/local/lib/python3.11/dist-packages (from pymatgen) (2.6.0)
# Requirement already satisfied: tabulate>=0.9 in /usr/local/lib/python3.11/dist-packages (from pymatgen) (0.9.0)
# Requirement already satisfied: uncertainties>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from pymatgen) (3.2.3)
# Requirement already satisfied: pyparsing>=2.0.3 in /usr/local/lib/python3.11/dist-packages (from bibtexparser>=1.4.0->pymatgen) (2.4.7)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.8->pymatgen) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.8->pymatgen) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.8->pymatgen) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.8->pymatgen) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.8->pymatgen) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.8->pymatgen) (11.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.8->pymatgen) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=1.5->matminer) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=1.5->matminer) (2025.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly>=5.0.0->pymatgen) (9.1.2)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from pymongo~=4.5->matminer) (2.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests~=2.31->matminer) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests~=2.31->matminer) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests~=2.31->matminer) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests~=2.31->matminer) (2025.4.26)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /usr/local/lib/python3.11/dist-packages (from ruamel.yaml>=0.17.0->pymatgen) (0.2.12)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn~=1.3->matminer) (3.6.0)
# Requirement already satisfied: typing-extensions>=4.9.0 in /usr/local/lib/python3.11/dist-packages (from spglib>=2.5->pymatgen) (4.13.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy~=1.11->matminer) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.8->pymatgen) (1.17.0)

# %%
import pandas as pd
import gzip
import json

# Castelli Perovskites データを読み込み（matminerの形式）
from matminer.datasets import load_dataset
df = load_dataset("castelli_perovskites")
df = df[df["gap gllbsc"].notnull()].reset_index(drop=True)

# 内容確認（任意）
df.head()
# Out:
# Fetching castelli_perovskites.json.gz from https://ndownloader.figshare.com/files/13284197 to /usr/local/lib/python3.11/dist-packages/matminer/datasets/castelli_perovskites.json.gz
# Fetching https://ndownloader.figshare.com/files/13284197 in MB: 4.9479679999999995MB [00:00, 372.53MB/s]
#    fermi level  fermi width  e_form  gap is direct  \
# 0     0.312138     0.001837    2.16           True
# 1     0.297083     0.001837    1.52           True
# 2     0.191139     0.003675    1.48           True
# 3     0.316346     0.001837    1.24           True
# 4     0.312658     0.003675    0.62           True
#
#                                            structure          mu_b  formula  \
# 0  [[0. 0. 0.] Rh, [1.97726555 1.97726555 1.97726...  1.974478e-02   RhTeN3
# 1  [[2.54041798 0.         0.        ] Hf, [1.020... -2.253054e-05   HfTeO3
# 2  [[0.60790913 0.         0.        ] Re, [2.186...  4.982109e+00  ReAsO2F
# 3  [[2.83091357 0.         0.        ] W, [2.6573... -8.684496e-01   WReO2S
# 4  [[0.00518937 0.         0.        ] Bi, [2.172...  2.164069e-15  BiHfO2F
#
#         vbm       cbm  gap gllbsc
# 0  6.187694  6.187694         0.0
# 1  6.033125  6.033125         0.0
# 2  6.602253  6.602253         0.0
# 3  5.738462  5.738462         0.0
# 4  6.074736  6.074736         0.0

# %%
from pymatgen.core import Structure
import os
from tqdm import tqdm

# 出力ディレクトリ作成
os.makedirs("data", exist_ok=True)
alignn_data = []

# 500件程度で軽く回す（必要に応じて増減可）
for i, row in tqdm(df[:500].iterrows(), total=500):
    try:
        struct = Structure.from_dict(row["structure"])
        gap = row["gap gllbsc"]
        fname = f"data/{i}.poscar"
        struct.to(fmt="poscar", filename=fname)
        alignn_data.append({"id": str(i), "target": gap, "poscar": fname})
    except Exception as e:
        print(f"Error at {i}: {e}")

# JSON形式で保存
with open("atomistic.json", "w") as f:
    json.dump(alignn_data, f, indent=2)
# Out:
# 100%|██████████| 500/500 [00:00<00:00, 17013.91it/s]
# Error at 0: list indices must be integers or slices, not str
# Error at 1: list indices must be integers or slices, not str
# Error at 2: list indices must be integers or slices, not str
# Error at 3: list indices must be integers or slices, not str
# Error at 4: list indices must be integers or slices, not str
# Error at 5: list indices must be integers or slices, not str
# Error at 6: list indices must be integers or slices, not str
# Error at 7: list indices must be integers or slices, not str
# Error at 8: list indices must be integers or slices, not str
# Error at 9: list indices must be integers or slices, not str
# Error at 10: list indices must be integers or slices, not str
# Error at 11: list indices must be integers or slices, not str
# Error at 12: list indices must be integers or slices, not str
# Error at 13: list indices must be integers or slices, not str
# Error at 14: list indices must be integers or slices, not str
# Error at 15: list indices must be integers or slices, not str
# Error at 16: list indices must be integers or slices, not str
# Error at 17: list indices must be integers or slices, not str
# Error at 18: list indices must be integers or slices, not str
# Error at 19: list indices must be integers or slices, not str
# Error at 20: list indices must be integers or slices, not str
# Error at 21: list indices must be integers or slices, not str
# Error at 22: list indices must be integers or slices, not str
# Error at 23: list indices must be integers or slices, not str
# Error at 24: list indices must be integers or slices, not str
# Error at 25: list indices must be integers or slices, not str
# Error at 26: list indices must be integers or slices, not str
# Error at 27: list indices must be integers or slices, not str
# Error at 28: list indices must be integers or slices, not str
# Error at 29: list indices must be integers or slices, not str
# Error at 30: list indices must be integers or slices, not str
# Error at 31: list indices must be integers or slices, not str
# Error at 32: list indices must be integers or slices, not str
# Error at 33: list indices must be integers or slices, not str
# Error at 34: list indices must be integers or slices, not str
# Error at 35: list indices must be integers or slices, not str
# Error at 36: list indices must be integers or slices, not str
# Error at 37: list indices must be integers or slices, not str
# Error at 38: list indices must be integers or slices, not str
# Error at 39: list indices must be integers or slices, not str
# Error at 40: list indices must be integers or slices, not str
# Error at 41: list indices must be integers or slices, not str
# Error at 42: list indices must be integers or slices, not str
# Error at 43: list indices must be integers or slices, not str
# Error at 44: list indices must be integers or slices, not str
# Error at 45: list indices must be integers or slices, not str
# Error at 46: list indices must be integers or slices, not str
# Error at 47: list indices must be integers or slices, not str
# Error at 48: list indices must be integers or slices, not str
# Error at 49: list indices must be integers or slices, not str
# Error at 50: list indices must be integers or slices, not str
# Error at 51: list indices must be integers or slices, not str
# Error at 52: list indices must be integers or slices, not str
# Error at 53: list indices must be integers or slices, not str
# Error at 54: list indices must be integers or slices, not str
# Error at 55: list indices must be integers or slices, not str
# Error at 56: list indices must be integers or slices, not str
# Error at 57: list indices must be integers or slices, not str
# Error at 58: list indices must be integers or slices, not str
# Error at 59: list indices must be integers or slices, not str
# Error at 60: list indices must be integers or slices, not str
# Error at 61: list indices must be integers or slices, not str
# Error at 62: list indices must be integers or slices, not str
# Error at 63: list indices must be integers or slices, not str
# Error at 64: list indices must be integers or slices, not str
# Error at 65: list indices must be integers or slices, not str
# Error at 66: list indices must be integers or slices, not str
# Error at 67: list indices must be integers or slices, not str
# Error at 68: list indices must be integers or slices, not str
# Error at 69: list indices must be integers or slices, not str
# Error at 70: list indices must be integers or slices, not str
# Error at 71: list indices must be integers or slices, not str
# Error at 72: list indices must be integers or slices, not str
# Error at 73: list indices must be integers or slices, not str
# Error at 74: list indices must be integers or slices, not str
# Error at 75: list indices must be integers or slices, not str
# Error at 76: list indices must be integers or slices, not str
# Error at 77: list indices must be integers or slices, not str
# Error at 78: list indices must be integers or slices, not str
# Error at 79: list indices must be integers or slices, not str
# Error at 80: list indices must be integers or slices, not str
# Error at 81: list indices must be integers or slices, not str
# Error at 82: list indices must be integers or slices, not str
# Error at 83: list indices must be integers or slices, not str
# Error at 84: list indices must be integers or slices, not str
# Error at 85: list indices must be integers or slices, not str
# Error at 86: list indices must be integers or slices, not str
# Error at 87: list indices must be integers or slices, not str
# Error at 88: list indices must be integers or slices, not str
# Error at 89: list indices must be integers or slices, not str
# Error at 90: list indices must be integers or slices, not str
# Error at 91: list indices must be integers or slices, not str
# Error at 92: list indices must be integers or slices, not str
# Error at 93: list indices must be integers or slices, not str
# Error at 94: list indices must be integers or slices, not str
# Error at 95: list indices must be integers or slices, not str
# Error at 96: list indices must be integers or slices, not str
# Error at 97: list indices must be integers or slices, not str
# Error at 98: list indices must be integers or slices, not str
# Error at 99: list indices must be integers or slices, not str
# Error at 100: list indices must be integers or slices, not str
# Error at 101: list indices must be integers or slices, not str
# Error at 102: list indices must be integers or slices, not str
# Error at 103: list indices must be integers or slices, not str
# Error at 104: list indices must be integers or slices, not str
# Error at 105: list indices must be integers or slices, not str
# Error at 106: list indices must be integers or slices, not str
# Error at 107: list indices must be integers or slices, not str
# Error at 108: list indices must be integers or slices, not str
# Error at 109: list indices must be integers or slices, not str
# Error at 110: list indices must be integers or slices, not str
# Error at 111: list indices must be integers or slices, not str
# Error at 112: list indices must be integers or slices, not str
# Error at 113: list indices must be integers or slices, not str
# Error at 114: list indices must be integers or slices, not str
# Error at 115: list indices must be integers or slices, not str
# Error at 116: list indices must be integers or slices, not str
# Error at 117: list indices must be integers or slices, not str
# Error at 118: list indices must be integers or slices, not str
# Error at 119: list indices must be integers or slices, not str
# Error at 120: list indices must be integers or slices, not str
# Error at 121: list indices must be integers or slices, not str
# Error at 122: list indices must be integers or slices, not str
# Error at 123: list indices must be integers or slices, not str
# Error at 124: list indices must be integers or slices, not str
# Error at 125: list indices must be integers or slices, not str
# Error at 126: list indices must be integers or slices, not str
# Error at 127: list indices must be integers or slices, not str
# Error at 128: list indices must be integers or slices, not str
# Error at 129: list indices must be integers or slices, not str
# Error at 130: list indices must be integers or slices, not str
# Error at 131: list indices must be integers or slices, not str
# Error at 132: list indices must be integers or slices, not str
# Error at 133: list indices must be integers or slices, not str
# Error at 134: list indices must be integers or slices, not str
# Error at 135: list indices must be integers or slices, not str
# Error at 136: list indices must be integers or slices, not str
# Error at 137: list indices must be integers or slices, not str
# Error at 138: list indices must be integers or slices, not str
# Error at 139: list indices must be integers or slices, not str
# Error at 140: list indices must be integers or slices, not str
# Error at 141: list indices must be integers or slices, not str
# Error at 142: list indices must be integers or slices, not str
# Error at 143: list indices must be integers or slices, not str
# Error at 144: list indices must be integers or slices, not str
# Error at 145: list indices must be integers or slices, not str
# Error at 146: list indices must be integers or slices, not str
# Error at 147: list indices must be integers or slices, not str
# Error at 148: list indices must be integers or slices, not str
# Error at 149: list indices must be integers or slices, not str
# Error at 150: list indices must be integers or slices, not str
# Error at 151: list indices must be integers or slices, not str
# Error at 152: list indices must be integers or slices, not str
# Error at 153: list indices must be integers or slices, not str
# Error at 154: list indices must be integers or slices, not str
# Error at 155: list indices must be integers or slices, not str
# Error at 156: list indices must be integers or slices, not str
# Error at 157: list indices must be integers or slices, not str
# Error at 158: list indices must be integers or slices, not str
# Error at 159: list indices must be integers or slices, not str
# Error at 160: list indices must be integers or slices, not str
# Error at 161: list indices must be integers or slices, not str
# Error at 162: list indices must be integers or slices, not str
# Error at 163: list indices must be integers or slices, not str
# Error at 164: list indices must be integers or slices, not str
# Error at 165: list indices must be integers or slices, not str
# Error at 166: list indices must be integers or slices, not str
# Error at 167: list indices must be integers or slices, not str
# Error at 168: list indices must be integers or slices, not str
# Error at 169: list indices must be integers or slices, not str
# Error at 170: list indices must be integers or slices, not str
# Error at 171: list indices must be integers or slices, not str
# Error at 172: list indices must be integers or slices, not str
# Error at 173: list indices must be integers or slices, not str
# Error at 174: list indices must be integers or slices, not str
# Error at 175: list indices must be integers or slices, not str
# Error at 176: list indices must be integers or slices, not str
# Error at 177: list indices must be integers or slices, not str
# Error at 178: list indices must be integers or slices, not str
# Error at 179: list indices must be integers or slices, not str
# Error at 180: list indices must be integers or slices, not str
# Error at 181: list indices must be integers or slices, not str
# Error at 182: list indices must be integers or slices, not str
# Error at 183: list indices must be integers or slices, not str
# Error at 184: list indices must be integers or slices, not str
# Error at 185: list indices must be integers or slices, not str
# Error at 186: list indices must be integers or slices, not str
# Error at 187: list indices must be integers or slices, not str
# Error at 188: list indices must be integers or slices, not str
# Error at 189: list indices must be integers or slices, not str
# Error at 190: list indices must be integers or slices, not str
# Error at 191: list indices must be integers or slices, not str
# Error at 192: list indices must be integers or slices, not str
# Error at 193: list indices must be integers or slices, not str
# Error at 194: list indices must be integers or slices, not str
# Error at 195: list indices must be integers or slices, not str
# Error at 196: list indices must be integers or slices, not str
# Error at 197: list indices must be integers or slices, not str
# Error at 198: list indices must be integers or slices, not str
# Error at 199: list indices must be integers or slices, not str
# Error at 200: list indices must be integers or slices, not str
# Error at 201: list indices must be integers or slices, not str
# Error at 202: list indices must be integers or slices, not str
# Error at 203: list indices must be integers or slices, not str
# Error at 204: list indices must be integers or slices, not str
# Error at 205: list indices must be integers or slices, not str
# Error at 206: list indices must be integers or slices, not str
# Error at 207: list indices must be integers or slices, not str
# Error at 208: list indices must be integers or slices, not str
# Error at 209: list indices must be integers or slices, not str
# Error at 210: list indices must be integers or slices, not str
# Error at 211: list indices must be integers or slices, not str
# Error at 212: list indices must be integers or slices, not str
# Error at 213: list indices must be integers or slices, not str
# Error at 214: list indices must be integers or slices, not str
# Error at 215: list indices must be integers or slices, not str
# Error at 216: list indices must be integers or slices, not str
# Error at 217: list indices must be integers or slices, not str
# Error at 218: list indices must be integers or slices, not str
# Error at 219: list indices must be integers or slices, not str
# Error at 220: list indices must be integers or slices, not str
# Error at 221: list indices must be integers or slices, not str
# Error at 222: list indices must be integers or slices, not str
# Error at 223: list indices must be integers or slices, not str
# Error at 224: list indices must be integers or slices, not str
# Error at 225: list indices must be integers or slices, not str
# Error at 226: list indices must be integers or slices, not str
# Error at 227: list indices must be integers or slices, not str
# Error at 228: list indices must be integers or slices, not str
# Error at 229: list indices must be integers or slices, not str
# Error at 230: list indices must be integers or slices, not str
# Error at 231: list indices must be integers or slices, not str
# Error at 232: list indices must be integers or slices, not str
# Error at 233: list indices must be integers or slices, not str
# Error at 234: list indices must be integers or slices, not str
# Error at 235: list indices must be integers or slices, not str
# Error at 236: list indices must be integers or slices, not str
# Error at 237: list indices must be integers or slices, not str
# Error at 238: list indices must be integers or slices, not str
# Error at 239: list indices must be integers or slices, not str
# Error at 240: list indices must be integers or slices, not str
# Error at 241: list indices must be integers or slices, not str
# Error at 242: list indices must be integers or slices, not str
# Error at 243: list indices must be integers or slices, not str
# Error at 244: list indices must be integers or slices, not str
# Error at 245: list indices must be integers or slices, not str
# Error at 246: list indices must be integers or slices, not str
# Error at 247: list indices must be integers or slices, not str
# Error at 248: list indices must be integers or slices, not str
# Error at 249: list indices must be integers or slices, not str
# Error at 250: list indices must be integers or slices, not str
# Error at 251: list indices must be integers or slices, not str
# Error at 252: list indices must be integers or slices, not str
# Error at 253: list indices must be integers or slices, not str
# Error at 254: list indices must be integers or slices, not str
# Error at 255: list indices must be integers or slices, not str
# Error at 256: list indices must be integers or slices, not str
# Error at 257: list indices must be integers or slices, not str
# Error at 258: list indices must be integers or slices, not str
# Error at 259: list indices must be integers or slices, not str
# Error at 260: list indices must be integers or slices, not str
# Error at 261: list indices must be integers or slices, not str
# Error at 262: list indices must be integers or slices, not str
# Error at 263: list indices must be integers or slices, not str
# Error at 264: list indices must be integers or slices, not str
# Error at 265: list indices must be integers or slices, not str
# Error at 266: list indices must be integers or slices, not str
# Error at 267: list indices must be integers or slices, not str
# Error at 268: list indices must be integers or slices, not str
# Error at 269: list indices must be integers or slices, not str
# Error at 270: list indices must be integers or slices, not str
# Error at 271: list indices must be integers or slices, not str
# Error at 272: list indices must be integers or slices, not str
# Error at 273: list indices must be integers or slices, not str
# Error at 274: list indices must be integers or slices, not str
# Error at 275: list indices must be integers or slices, not str
# Error at 276: list indices must be integers or slices, not str
# Error at 277: list indices must be integers or slices, not str
# Error at 278: list indices must be integers or slices, not str
# Error at 279: list indices must be integers or slices, not str
# Error at 280: list indices must be integers or slices, not str
# Error at 281: list indices must be integers or slices, not str
# Error at 282: list indices must be integers or slices, not str
# Error at 283: list indices must be integers or slices, not str
# Error at 284: list indices must be integers or slices, not str
# Error at 285: list indices must be integers or slices, not str
# Error at 286: list indices must be integers or slices, not str
# Error at 287: list indices must be integers or slices, not str
# Error at 288: list indices must be integers or slices, not str
# Error at 289: list indices must be integers or slices, not str
# Error at 290: list indices must be integers or slices, not str
# Error at 291: list indices must be integers or slices, not str
# Error at 292: list indices must be integers or slices, not str
# Error at 293: list indices must be integers or slices, not str
# Error at 294: list indices must be integers or slices, not str
# Error at 295: list indices must be integers or slices, not str
# Error at 296: list indices must be integers or slices, not str
# Error at 297: list indices must be integers or slices, not str
# Error at 298: list indices must be integers or slices, not str
# Error at 299: list indices must be integers or slices, not str
# Error at 300: list indices must be integers or slices, not str
# Error at 301: list indices must be integers or slices, not str
# Error at 302: list indices must be integers or slices, not str
# Error at 303: list indices must be integers or slices, not str
# Error at 304: list indices must be integers or slices, not str
# Error at 305: list indices must be integers or slices, not str
# Error at 306: list indices must be integers or slices, not str
# Error at 307: list indices must be integers or slices, not str
# Error at 308: list indices must be integers or slices, not str
# Error at 309: list indices must be integers or slices, not str
# Error at 310: list indices must be integers or slices, not str
# Error at 311: list indices must be integers or slices, not str
# Error at 312: list indices must be integers or slices, not str
# Error at 313: list indices must be integers or slices, not str
# Error at 314: list indices must be integers or slices, not str
# Error at 315: list indices must be integers or slices, not str
# Error at 316: list indices must be integers or slices, not str
# Error at 317: list indices must be integers or slices, not str
# Error at 318: list indices must be integers or slices, not str
# Error at 319: list indices must be integers or slices, not str
# Error at 320: list indices must be integers or slices, not str
# Error at 321: list indices must be integers or slices, not str
# Error at 322: list indices must be integers or slices, not str
# Error at 323: list indices must be integers or slices, not str
# Error at 324: list indices must be integers or slices, not str
# Error at 325: list indices must be integers or slices, not str
# Error at 326: list indices must be integers or slices, not str
# Error at 327: list indices must be integers or slices, not str
# Error at 328: list indices must be integers or slices, not str
# Error at 329: list indices must be integers or slices, not str
# Error at 330: list indices must be integers or slices, not str
# Error at 331: list indices must be integers or slices, not str
# Error at 332: list indices must be integers or slices, not str
# Error at 333: list indices must be integers or slices, not str
# Error at 334: list indices must be integers or slices, not str
# Error at 335: list indices must be integers or slices, not str
# Error at 336: list indices must be integers or slices, not str
# Error at 337: list indices must be integers or slices, not str
# Error at 338: list indices must be integers or slices, not str
# Error at 339: list indices must be integers or slices, not str
# Error at 340: list indices must be integers or slices, not str
# Error at 341: list indices must be integers or slices, not str
# Error at 342: list indices must be integers or slices, not str
# Error at 343: list indices must be integers or slices, not str
# Error at 344: list indices must be integers or slices, not str
# Error at 345: list indices must be integers or slices, not str
# Error at 346: list indices must be integers or slices, not str
# Error at 347: list indices must be integers or slices, not str
# Error at 348: list indices must be integers or slices, not str
# Error at 349: list indices must be integers or slices, not str
# Error at 350: list indices must be integers or slices, not str
# Error at 351: list indices must be integers or slices, not str
# Error at 352: list indices must be integers or slices, not str
# Error at 353: list indices must be integers or slices, not str
# Error at 354: list indices must be integers or slices, not str
# Error at 355: list indices must be integers or slices, not str
# Error at 356: list indices must be integers or slices, not str
# Error at 357: list indices must be integers or slices, not str
# Error at 358: list indices must be integers or slices, not str
# Error at 359: list indices must be integers or slices, not str
# Error at 360: list indices must be integers or slices, not str
# Error at 361: list indices must be integers or slices, not str
# Error at 362: list indices must be integers or slices, not str
# Error at 363: list indices must be integers or slices, not str
# Error at 364: list indices must be integers or slices, not str
# Error at 365: list indices must be integers or slices, not str
# Error at 366: list indices must be integers or slices, not str
# Error at 367: list indices must be integers or slices, not str
# Error at 368: list indices must be integers or slices, not str
# Error at 369: list indices must be integers or slices, not str
# Error at 370: list indices must be integers or slices, not str
# Error at 371: list indices must be integers or slices, not str
# Error at 372: list indices must be integers or slices, not str
# Error at 373: list indices must be integers or slices, not str
# Error at 374: list indices must be integers or slices, not str
# Error at 375: list indices must be integers or slices, not str
# Error at 376: list indices must be integers or slices, not str
# Error at 377: list indices must be integers or slices, not str
# Error at 378: list indices must be integers or slices, not str
# Error at 379: list indices must be integers or slices, not str
# Error at 380: list indices must be integers or slices, not str
# Error at 381: list indices must be integers or slices, not str
# Error at 382: list indices must be integers or slices, not str
# Error at 383: list indices must be integers or slices, not str
# Error at 384: list indices must be integers or slices, not str
# Error at 385: list indices must be integers or slices, not str
# Error at 386: list indices must be integers or slices, not str
# Error at 387: list indices must be integers or slices, not str
# Error at 388: list indices must be integers or slices, not str
# Error at 389: list indices must be integers or slices, not str
# Error at 390: list indices must be integers or slices, not str
# Error at 391: list indices must be integers or slices, not str
# Error at 392: list indices must be integers or slices, not str
# Error at 393: list indices must be integers or slices, not str
# Error at 394: list indices must be integers or slices, not str
# Error at 395: list indices must be integers or slices, not str
# Error at 396: list indices must be integers or slices, not str
# Error at 397: list indices must be integers or slices, not str
# Error at 398: list indices must be integers or slices, not str
# Error at 399: list indices must be integers or slices, not str
# Error at 400: list indices must be integers or slices, not str
# Error at 401: list indices must be integers or slices, not str
# Error at 402: list indices must be integers or slices, not str
# Error at 403: list indices must be integers or slices, not str
# Error at 404: list indices must be integers or slices, not str
# Error at 405: list indices must be integers or slices, not str
# Error at 406: list indices must be integers or slices, not str
# Error at 407: list indices must be integers or slices, not str
# Error at 408: list indices must be integers or slices, not str
# Error at 409: list indices must be integers or slices, not str
# Error at 410: list indices must be integers or slices, not str
# Error at 411: list indices must be integers or slices, not str
# Error at 412: list indices must be integers or slices, not str
# Error at 413: list indices must be integers or slices, not str
# Error at 414: list indices must be integers or slices, not str
# Error at 415: list indices must be integers or slices, not str
# Error at 416: list indices must be integers or slices, not str
# Error at 417: list indices must be integers or slices, not str
# Error at 418: list indices must be integers or slices, not str
# Error at 419: list indices must be integers or slices, not str
# Error at 420: list indices must be integers or slices, not str
# Error at 421: list indices must be integers or slices, not str
# Error at 422: list indices must be integers or slices, not str
# Error at 423: list indices must be integers or slices, not str
# Error at 424: list indices must be integers or slices, not str
# Error at 425: list indices must be integers or slices, not str
# Error at 426: list indices must be integers or slices, not str
# Error at 427: list indices must be integers or slices, not str
# Error at 428: list indices must be integers or slices, not str
# Error at 429: list indices must be integers or slices, not str
# Error at 430: list indices must be integers or slices, not str
# Error at 431: list indices must be integers or slices, not str
# Error at 432: list indices must be integers or slices, not str
# Error at 433: list indices must be integers or slices, not str
# Error at 434: list indices must be integers or slices, not str
# Error at 435: list indices must be integers or slices, not str
# Error at 436: list indices must be integers or slices, not str
# Error at 437: list indices must be integers or slices, not str
# Error at 438: list indices must be integers or slices, not str
# Error at 439: list indices must be integers or slices, not str
# Error at 440: list indices must be integers or slices, not str
# Error at 441: list indices must be integers or slices, not str
# Error at 442: list indices must be integers or slices, not str
# Error at 443: list indices must be integers or slices, not str
# Error at 444: list indices must be integers or slices, not str
# Error at 445: list indices must be integers or slices, not str
# Error at 446: list indices must be integers or slices, not str
# Error at 447: list indices must be integers or slices, not str
# Error at 448: list indices must be integers or slices, not str
# Error at 449: list indices must be integers or slices, not str
# Error at 450: list indices must be integers or slices, not str
# Error at 451: list indices must be integers or slices, not str
# Error at 452: list indices must be integers or slices, not str
# Error at 453: list indices must be integers or slices, not str
# Error at 454: list indices must be integers or slices, not str
# Error at 455: list indices must be integers or slices, not str
# Error at 456: list indices must be integers or slices, not str
# Error at 457: list indices must be integers or slices, not str
# Error at 458: list indices must be integers or slices, not str
# Error at 459: list indices must be integers or slices, not str
# Error at 460: list indices must be integers or slices, not str
# Error at 461: list indices must be integers or slices, not str
# Error at 462: list indices must be integers or slices, not str
# Error at 463: list indices must be integers or slices, not str
# Error at 464: list indices must be integers or slices, not str
# Error at 465: list indices must be integers or slices, not str
# Error at 466: list indices must be integers or slices, not str
# Error at 467: list indices must be integers or slices, not str
# Error at 468: list indices must be integers or slices, not str
# Error at 469: list indices must be integers or slices, not str
# Error at 470: list indices must be integers or slices, not str
# Error at 471: list indices must be integers or slices, not str
# Error at 472: list indices must be integers or slices, not str
# Error at 473: list indices must be integers or slices, not str
# Error at 474: list indices must be integers or slices, not str
# Error at 475: list indices must be integers or slices, not str
# Error at 476: list indices must be integers or slices, not str
# Error at 477: list indices must be integers or slices, not str
# Error at 478: list indices must be integers or slices, not str
# Error at 479: list indices must be integers or slices, not str
# Error at 480: list indices must be integers or slices, not str
# Error at 481: list indices must be integers or slices, not str
# Error at 482: list indices must be integers or slices, not str
# Error at 483: list indices must be integers or slices, not str
# Error at 484: list indices must be integers or slices, not str
# Error at 485: list indices must be integers or slices, not str
# Error at 486: list indices must be integers or slices, not str
# Error at 487: list indices must be integers or slices, not str
# Error at 488: list indices must be integers or slices, not str
# Error at 489: list indices must be integers or slices, not str
# Error at 490: list indices must be integers or slices, not str
# Error at 491: list indices must be integers or slices, not str
# Error at 492: list indices must be integers or slices, not str
# Error at 493: list indices must be integers or slices, not str
# Error at 494: list indices must be integers or slices, not str
# Error at 495: list indices must be integers or slices, not str
# Error at 496: list indices must be integers or slices, not str
# Error at 497: list indices must be integers or slices, not str
# Error at 498: list indices must be integers or slices, not str
# Error at 499: list indices must be integers or slices, not str

# %%
from alignn.train_config import TrainingConfig

cfg = TrainingConfig(
    dataset="atomistic.json",
    output_dir="alignn_out",
    batch_size=32,
    epochs=20,
    learning_rate=0.001,
    task="regression",
    prediction_type="atomistic"
)

with open("config.json", "w") as f:
    json.dump(cfg.as_dict(), f, indent=2)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-0489b6040e2a> in <cell line: 0>()
# ----> 1 from alignn.train_config import TrainingConfig
#       2
#       3 cfg = TrainingConfig(
#       4     dataset="atomistic.json",
#       5     output_dir="alignn_out",
#
# ModuleNotFoundError: No module named 'alignn.train_config'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from pymatgen.core import Structure
import os
from tqdm import tqdm
import json

os.makedirs("data", exist_ok=True)
alignn_data = []

# エラーなく最大500件処理する
for i, row in tqdm(df.iloc[:500].iterrows(), total=500):
    try:
        struct = Structure.from_dict(row["structure"])
        gap = row["gap gllbsc"]
        fname = f"data/{i}.poscar"
        struct.to(fmt="poscar", filename=fname)
        alignn_data.append({
            "id": str(i),
            "target": gap,
            "poscar": fname
        })
    except Exception as e:
        print(f"Error at {i}: {e}")

# JSONに保存
with open("atomistic.json", "w") as f:
    json.dump(alignn_data, f, indent=2)
# Out:
# 100%|██████████| 500/500 [00:00<00:00, 16613.61it/s]
# Error at 0: list indices must be integers or slices, not str
# Error at 1: list indices must be integers or slices, not str
# Error at 2: list indices must be integers or slices, not str
# Error at 3: list indices must be integers or slices, not str
# Error at 4: list indices must be integers or slices, not str
# Error at 5: list indices must be integers or slices, not str
# Error at 6: list indices must be integers or slices, not str
# Error at 7: list indices must be integers or slices, not str
# Error at 8: list indices must be integers or slices, not str
# Error at 9: list indices must be integers or slices, not str
# Error at 10: list indices must be integers or slices, not str
# Error at 11: list indices must be integers or slices, not str
# Error at 12: list indices must be integers or slices, not str
# Error at 13: list indices must be integers or slices, not str
# Error at 14: list indices must be integers or slices, not str
# Error at 15: list indices must be integers or slices, not str
# Error at 16: list indices must be integers or slices, not str
# Error at 17: list indices must be integers or slices, not str
# Error at 18: list indices must be integers or slices, not str
# Error at 19: list indices must be integers or slices, not str
# Error at 20: list indices must be integers or slices, not str
# Error at 21: list indices must be integers or slices, not str
# Error at 22: list indices must be integers or slices, not str
# Error at 23: list indices must be integers or slices, not str
# Error at 24: list indices must be integers or slices, not str
# Error at 25: list indices must be integers or slices, not str
# Error at 26: list indices must be integers or slices, not str
# Error at 27: list indices must be integers or slices, not str
# Error at 28: list indices must be integers or slices, not str
# Error at 29: list indices must be integers or slices, not str
# Error at 30: list indices must be integers or slices, not str
# Error at 31: list indices must be integers or slices, not str
# Error at 32: list indices must be integers or slices, not str
# Error at 33: list indices must be integers or slices, not str
# Error at 34: list indices must be integers or slices, not str
# Error at 35: list indices must be integers or slices, not str
# Error at 36: list indices must be integers or slices, not str
# Error at 37: list indices must be integers or slices, not str
# Error at 38: list indices must be integers or slices, not str
# Error at 39: list indices must be integers or slices, not str
# Error at 40: list indices must be integers or slices, not str
# Error at 41: list indices must be integers or slices, not str
# Error at 42: list indices must be integers or slices, not str
# Error at 43: list indices must be integers or slices, not str
# Error at 44: list indices must be integers or slices, not str
# Error at 45: list indices must be integers or slices, not str
# Error at 46: list indices must be integers or slices, not str
# Error at 47: list indices must be integers or slices, not str
# Error at 48: list indices must be integers or slices, not str
# Error at 49: list indices must be integers or slices, not str
# Error at 50: list indices must be integers or slices, not str
# Error at 51: list indices must be integers or slices, not str
# Error at 52: list indices must be integers or slices, not str
# Error at 53: list indices must be integers or slices, not str
# Error at 54: list indices must be integers or slices, not str
# Error at 55: list indices must be integers or slices, not str
# Error at 56: list indices must be integers or slices, not str
# Error at 57: list indices must be integers or slices, not str
# Error at 58: list indices must be integers or slices, not str
# Error at 59: list indices must be integers or slices, not str
# Error at 60: list indices must be integers or slices, not str
# Error at 61: list indices must be integers or slices, not str
# Error at 62: list indices must be integers or slices, not str
# Error at 63: list indices must be integers or slices, not str
# Error at 64: list indices must be integers or slices, not str
# Error at 65: list indices must be integers or slices, not str
# Error at 66: list indices must be integers or slices, not str
# Error at 67: list indices must be integers or slices, not str
# Error at 68: list indices must be integers or slices, not str
# Error at 69: list indices must be integers or slices, not str
# Error at 70: list indices must be integers or slices, not str
# Error at 71: list indices must be integers or slices, not str
# Error at 72: list indices must be integers or slices, not str
# Error at 73: list indices must be integers or slices, not str
# Error at 74: list indices must be integers or slices, not str
# Error at 75: list indices must be integers or slices, not str
# Error at 76: list indices must be integers or slices, not str
# Error at 77: list indices must be integers or slices, not str
# Error at 78: list indices must be integers or slices, not str
# Error at 79: list indices must be integers or slices, not str
# Error at 80: list indices must be integers or slices, not str
# Error at 81: list indices must be integers or slices, not str
# Error at 82: list indices must be integers or slices, not str
# Error at 83: list indices must be integers or slices, not str
# Error at 84: list indices must be integers or slices, not str
# Error at 85: list indices must be integers or slices, not str
# Error at 86: list indices must be integers or slices, not str
# Error at 87: list indices must be integers or slices, not str
# Error at 88: list indices must be integers or slices, not str
# Error at 89: list indices must be integers or slices, not str
# Error at 90: list indices must be integers or slices, not str
# Error at 91: list indices must be integers or slices, not str
# Error at 92: list indices must be integers or slices, not str
# Error at 93: list indices must be integers or slices, not str
# Error at 94: list indices must be integers or slices, not str
# Error at 95: list indices must be integers or slices, not str
# Error at 96: list indices must be integers or slices, not str
# Error at 97: list indices must be integers or slices, not str
# Error at 98: list indices must be integers or slices, not str
# Error at 99: list indices must be integers or slices, not str
# Error at 100: list indices must be integers or slices, not str
# Error at 101: list indices must be integers or slices, not str
# Error at 102: list indices must be integers or slices, not str
# Error at 103: list indices must be integers or slices, not str
# Error at 104: list indices must be integers or slices, not str
# Error at 105: list indices must be integers or slices, not str
# Error at 106: list indices must be integers or slices, not str
# Error at 107: list indices must be integers or slices, not str
# Error at 108: list indices must be integers or slices, not str
# Error at 109: list indices must be integers or slices, not str
# Error at 110: list indices must be integers or slices, not str
# Error at 111: list indices must be integers or slices, not str
# Error at 112: list indices must be integers or slices, not str
# Error at 113: list indices must be integers or slices, not str
# Error at 114: list indices must be integers or slices, not str
# Error at 115: list indices must be integers or slices, not str
# Error at 116: list indices must be integers or slices, not str
# Error at 117: list indices must be integers or slices, not str
# Error at 118: list indices must be integers or slices, not str
# Error at 119: list indices must be integers or slices, not str
# Error at 120: list indices must be integers or slices, not str
# Error at 121: list indices must be integers or slices, not str
# Error at 122: list indices must be integers or slices, not str
# Error at 123: list indices must be integers or slices, not str
# Error at 124: list indices must be integers or slices, not str
# Error at 125: list indices must be integers or slices, not str
# Error at 126: list indices must be integers or slices, not str
# Error at 127: list indices must be integers or slices, not str
# Error at 128: list indices must be integers or slices, not str
# Error at 129: list indices must be integers or slices, not str
# Error at 130: list indices must be integers or slices, not str
# Error at 131: list indices must be integers or slices, not str
# Error at 132: list indices must be integers or slices, not str
# Error at 133: list indices must be integers or slices, not str
# Error at 134: list indices must be integers or slices, not str
# Error at 135: list indices must be integers or slices, not str
# Error at 136: list indices must be integers or slices, not str
# Error at 137: list indices must be integers or slices, not str
# Error at 138: list indices must be integers or slices, not str
# Error at 139: list indices must be integers or slices, not str
# Error at 140: list indices must be integers or slices, not str
# Error at 141: list indices must be integers or slices, not str
# Error at 142: list indices must be integers or slices, not str
# Error at 143: list indices must be integers or slices, not str
# Error at 144: list indices must be integers or slices, not str
# Error at 145: list indices must be integers or slices, not str
# Error at 146: list indices must be integers or slices, not str
# Error at 147: list indices must be integers or slices, not str
# Error at 148: list indices must be integers or slices, not str
# Error at 149: list indices must be integers or slices, not str
# Error at 150: list indices must be integers or slices, not str
# Error at 151: list indices must be integers or slices, not str
# Error at 152: list indices must be integers or slices, not str
# Error at 153: list indices must be integers or slices, not str
# Error at 154: list indices must be integers or slices, not str
# Error at 155: list indices must be integers or slices, not str
# Error at 156: list indices must be integers or slices, not str
# Error at 157: list indices must be integers or slices, not str
# Error at 158: list indices must be integers or slices, not str
# Error at 159: list indices must be integers or slices, not str
# Error at 160: list indices must be integers or slices, not str
# Error at 161: list indices must be integers or slices, not str
# Error at 162: list indices must be integers or slices, not str
# Error at 163: list indices must be integers or slices, not str
# Error at 164: list indices must be integers or slices, not str
# Error at 165: list indices must be integers or slices, not str
# Error at 166: list indices must be integers or slices, not str
# Error at 167: list indices must be integers or slices, not str
# Error at 168: list indices must be integers or slices, not str
# Error at 169: list indices must be integers or slices, not str
# Error at 170: list indices must be integers or slices, not str
# Error at 171: list indices must be integers or slices, not str
# Error at 172: list indices must be integers or slices, not str
# Error at 173: list indices must be integers or slices, not str
# Error at 174: list indices must be integers or slices, not str
# Error at 175: list indices must be integers or slices, not str
# Error at 176: list indices must be integers or slices, not str
# Error at 177: list indices must be integers or slices, not str
# Error at 178: list indices must be integers or slices, not str
# Error at 179: list indices must be integers or slices, not str
# Error at 180: list indices must be integers or slices, not str
# Error at 181: list indices must be integers or slices, not str
# Error at 182: list indices must be integers or slices, not str
# Error at 183: list indices must be integers or slices, not str
# Error at 184: list indices must be integers or slices, not str
# Error at 185: list indices must be integers or slices, not str
# Error at 186: list indices must be integers or slices, not str
# Error at 187: list indices must be integers or slices, not str
# Error at 188: list indices must be integers or slices, not str
# Error at 189: list indices must be integers or slices, not str
# Error at 190: list indices must be integers or slices, not str
# Error at 191: list indices must be integers or slices, not str
# Error at 192: list indices must be integers or slices, not str
# Error at 193: list indices must be integers or slices, not str
# Error at 194: list indices must be integers or slices, not str
# Error at 195: list indices must be integers or slices, not str
# Error at 196: list indices must be integers or slices, not str
# Error at 197: list indices must be integers or slices, not str
# Error at 198: list indices must be integers or slices, not str
# Error at 199: list indices must be integers or slices, not str
# Error at 200: list indices must be integers or slices, not str
# Error at 201: list indices must be integers or slices, not str
# Error at 202: list indices must be integers or slices, not str
# Error at 203: list indices must be integers or slices, not str
# Error at 204: list indices must be integers or slices, not str
# Error at 205: list indices must be integers or slices, not str
# Error at 206: list indices must be integers or slices, not str
# Error at 207: list indices must be integers or slices, not str
# Error at 208: list indices must be integers or slices, not str
# Error at 209: list indices must be integers or slices, not str
# Error at 210: list indices must be integers or slices, not str
# Error at 211: list indices must be integers or slices, not str
# Error at 212: list indices must be integers or slices, not str
# Error at 213: list indices must be integers or slices, not str
# Error at 214: list indices must be integers or slices, not str
# Error at 215: list indices must be integers or slices, not str
# Error at 216: list indices must be integers or slices, not str
# Error at 217: list indices must be integers or slices, not str
# Error at 218: list indices must be integers or slices, not str
# Error at 219: list indices must be integers or slices, not str
# Error at 220: list indices must be integers or slices, not str
# Error at 221: list indices must be integers or slices, not str
# Error at 222: list indices must be integers or slices, not str
# Error at 223: list indices must be integers or slices, not str
# Error at 224: list indices must be integers or slices, not str
# Error at 225: list indices must be integers or slices, not str
# Error at 226: list indices must be integers or slices, not str
# Error at 227: list indices must be integers or slices, not str
# Error at 228: list indices must be integers or slices, not str
# Error at 229: list indices must be integers or slices, not str
# Error at 230: list indices must be integers or slices, not str
# Error at 231: list indices must be integers or slices, not str
# Error at 232: list indices must be integers or slices, not str
# Error at 233: list indices must be integers or slices, not str
# Error at 234: list indices must be integers or slices, not str
# Error at 235: list indices must be integers or slices, not str
# Error at 236: list indices must be integers or slices, not str
# Error at 237: list indices must be integers or slices, not str
# Error at 238: list indices must be integers or slices, not str
# Error at 239: list indices must be integers or slices, not str
# Error at 240: list indices must be integers or slices, not str
# Error at 241: list indices must be integers or slices, not str
# Error at 242: list indices must be integers or slices, not str
# Error at 243: list indices must be integers or slices, not str
# Error at 244: list indices must be integers or slices, not str
# Error at 245: list indices must be integers or slices, not str
# Error at 246: list indices must be integers or slices, not str
# Error at 247: list indices must be integers or slices, not str
# Error at 248: list indices must be integers or slices, not str
# Error at 249: list indices must be integers or slices, not str
# Error at 250: list indices must be integers or slices, not str
# Error at 251: list indices must be integers or slices, not str
# Error at 252: list indices must be integers or slices, not str
# Error at 253: list indices must be integers or slices, not str
# Error at 254: list indices must be integers or slices, not str
# Error at 255: list indices must be integers or slices, not str
# Error at 256: list indices must be integers or slices, not str
# Error at 257: list indices must be integers or slices, not str
# Error at 258: list indices must be integers or slices, not str
# Error at 259: list indices must be integers or slices, not str
# Error at 260: list indices must be integers or slices, not str
# Error at 261: list indices must be integers or slices, not str
# Error at 262: list indices must be integers or slices, not str
# Error at 263: list indices must be integers or slices, not str
# Error at 264: list indices must be integers or slices, not str
# Error at 265: list indices must be integers or slices, not str
# Error at 266: list indices must be integers or slices, not str
# Error at 267: list indices must be integers or slices, not str
# Error at 268: list indices must be integers or slices, not str
# Error at 269: list indices must be integers or slices, not str
# Error at 270: list indices must be integers or slices, not str
# Error at 271: list indices must be integers or slices, not str
# Error at 272: list indices must be integers or slices, not str
# Error at 273: list indices must be integers or slices, not str
# Error at 274: list indices must be integers or slices, not str
# Error at 275: list indices must be integers or slices, not str
# Error at 276: list indices must be integers or slices, not str
# Error at 277: list indices must be integers or slices, not str
# Error at 278: list indices must be integers or slices, not str
# Error at 279: list indices must be integers or slices, not str
# Error at 280: list indices must be integers or slices, not str
# Error at 281: list indices must be integers or slices, not str
# Error at 282: list indices must be integers or slices, not str
# Error at 283: list indices must be integers or slices, not str
# Error at 284: list indices must be integers or slices, not str
# Error at 285: list indices must be integers or slices, not str
# Error at 286: list indices must be integers or slices, not str
# Error at 287: list indices must be integers or slices, not str
# Error at 288: list indices must be integers or slices, not str
# Error at 289: list indices must be integers or slices, not str
# Error at 290: list indices must be integers or slices, not str
# Error at 291: list indices must be integers or slices, not str
# Error at 292: list indices must be integers or slices, not str
# Error at 293: list indices must be integers or slices, not str
# Error at 294: list indices must be integers or slices, not str
# Error at 295: list indices must be integers or slices, not str
# Error at 296: list indices must be integers or slices, not str
# Error at 297: list indices must be integers or slices, not str
# Error at 298: list indices must be integers or slices, not str
# Error at 299: list indices must be integers or slices, not str
# Error at 300: list indices must be integers or slices, not str
# Error at 301: list indices must be integers or slices, not str
# Error at 302: list indices must be integers or slices, not str
# Error at 303: list indices must be integers or slices, not str
# Error at 304: list indices must be integers or slices, not str
# Error at 305: list indices must be integers or slices, not str
# Error at 306: list indices must be integers or slices, not str
# Error at 307: list indices must be integers or slices, not str
# Error at 308: list indices must be integers or slices, not str
# Error at 309: list indices must be integers or slices, not str
# Error at 310: list indices must be integers or slices, not str
# Error at 311: list indices must be integers or slices, not str
# Error at 312: list indices must be integers or slices, not str
# Error at 313: list indices must be integers or slices, not str
# Error at 314: list indices must be integers or slices, not str
# Error at 315: list indices must be integers or slices, not str
# Error at 316: list indices must be integers or slices, not str
# Error at 317: list indices must be integers or slices, not str
# Error at 318: list indices must be integers or slices, not str
# Error at 319: list indices must be integers or slices, not str
# Error at 320: list indices must be integers or slices, not str
# Error at 321: list indices must be integers or slices, not str
# Error at 322: list indices must be integers or slices, not str
# Error at 323: list indices must be integers or slices, not str
# Error at 324: list indices must be integers or slices, not str
# Error at 325: list indices must be integers or slices, not str
# Error at 326: list indices must be integers or slices, not str
# Error at 327: list indices must be integers or slices, not str
# Error at 328: list indices must be integers or slices, not str
# Error at 329: list indices must be integers or slices, not str
# Error at 330: list indices must be integers or slices, not str
# Error at 331: list indices must be integers or slices, not str
# Error at 332: list indices must be integers or slices, not str
# Error at 333: list indices must be integers or slices, not str
# Error at 334: list indices must be integers or slices, not str
# Error at 335: list indices must be integers or slices, not str
# Error at 336: list indices must be integers or slices, not str
# Error at 337: list indices must be integers or slices, not str
# Error at 338: list indices must be integers or slices, not str
# Error at 339: list indices must be integers or slices, not str
# Error at 340: list indices must be integers or slices, not str
# Error at 341: list indices must be integers or slices, not str
# Error at 342: list indices must be integers or slices, not str
# Error at 343: list indices must be integers or slices, not str
# Error at 344: list indices must be integers or slices, not str
# Error at 345: list indices must be integers or slices, not str
# Error at 346: list indices must be integers or slices, not str
# Error at 347: list indices must be integers or slices, not str
# Error at 348: list indices must be integers or slices, not str
# Error at 349: list indices must be integers or slices, not str
# Error at 350: list indices must be integers or slices, not str
# Error at 351: list indices must be integers or slices, not str
# Error at 352: list indices must be integers or slices, not str
# Error at 353: list indices must be integers or slices, not str
# Error at 354: list indices must be integers or slices, not str
# Error at 355: list indices must be integers or slices, not str
# Error at 356: list indices must be integers or slices, not str
# Error at 357: list indices must be integers or slices, not str
# Error at 358: list indices must be integers or slices, not str
# Error at 359: list indices must be integers or slices, not str
# Error at 360: list indices must be integers or slices, not str
# Error at 361: list indices must be integers or slices, not str
# Error at 362: list indices must be integers or slices, not str
# Error at 363: list indices must be integers or slices, not str
# Error at 364: list indices must be integers or slices, not str
# Error at 365: list indices must be integers or slices, not str
# Error at 366: list indices must be integers or slices, not str
# Error at 367: list indices must be integers or slices, not str
# Error at 368: list indices must be integers or slices, not str
# Error at 369: list indices must be integers or slices, not str
# Error at 370: list indices must be integers or slices, not str
# Error at 371: list indices must be integers or slices, not str
# Error at 372: list indices must be integers or slices, not str
# Error at 373: list indices must be integers or slices, not str
# Error at 374: list indices must be integers or slices, not str
# Error at 375: list indices must be integers or slices, not str
# Error at 376: list indices must be integers or slices, not str
# Error at 377: list indices must be integers or slices, not str
# Error at 378: list indices must be integers or slices, not str
# Error at 379: list indices must be integers or slices, not str
# Error at 380: list indices must be integers or slices, not str
# Error at 381: list indices must be integers or slices, not str
# Error at 382: list indices must be integers or slices, not str
# Error at 383: list indices must be integers or slices, not str
# Error at 384: list indices must be integers or slices, not str
# Error at 385: list indices must be integers or slices, not str
# Error at 386: list indices must be integers or slices, not str
# Error at 387: list indices must be integers or slices, not str
# Error at 388: list indices must be integers or slices, not str
# Error at 389: list indices must be integers or slices, not str
# Error at 390: list indices must be integers or slices, not str
# Error at 391: list indices must be integers or slices, not str
# Error at 392: list indices must be integers or slices, not str
# Error at 393: list indices must be integers or slices, not str
# Error at 394: list indices must be integers or slices, not str
# Error at 395: list indices must be integers or slices, not str
# Error at 396: list indices must be integers or slices, not str
# Error at 397: list indices must be integers or slices, not str
# Error at 398: list indices must be integers or slices, not str
# Error at 399: list indices must be integers or slices, not str
# Error at 400: list indices must be integers or slices, not str
# Error at 401: list indices must be integers or slices, not str
# Error at 402: list indices must be integers or slices, not str
# Error at 403: list indices must be integers or slices, not str
# Error at 404: list indices must be integers or slices, not str
# Error at 405: list indices must be integers or slices, not str
# Error at 406: list indices must be integers or slices, not str
# Error at 407: list indices must be integers or slices, not str
# Error at 408: list indices must be integers or slices, not str
# Error at 409: list indices must be integers or slices, not str
# Error at 410: list indices must be integers or slices, not str
# Error at 411: list indices must be integers or slices, not str
# Error at 412: list indices must be integers or slices, not str
# Error at 413: list indices must be integers or slices, not str
# Error at 414: list indices must be integers or slices, not str
# Error at 415: list indices must be integers or slices, not str
# Error at 416: list indices must be integers or slices, not str
# Error at 417: list indices must be integers or slices, not str
# Error at 418: list indices must be integers or slices, not str
# Error at 419: list indices must be integers or slices, not str
# Error at 420: list indices must be integers or slices, not str
# Error at 421: list indices must be integers or slices, not str
# Error at 422: list indices must be integers or slices, not str
# Error at 423: list indices must be integers or slices, not str
# Error at 424: list indices must be integers or slices, not str
# Error at 425: list indices must be integers or slices, not str
# Error at 426: list indices must be integers or slices, not str
# Error at 427: list indices must be integers or slices, not str
# Error at 428: list indices must be integers or slices, not str
# Error at 429: list indices must be integers or slices, not str
# Error at 430: list indices must be integers or slices, not str
# Error at 431: list indices must be integers or slices, not str
# Error at 432: list indices must be integers or slices, not str
# Error at 433: list indices must be integers or slices, not str
# Error at 434: list indices must be integers or slices, not str
# Error at 435: list indices must be integers or slices, not str
# Error at 436: list indices must be integers or slices, not str
# Error at 437: list indices must be integers or slices, not str
# Error at 438: list indices must be integers or slices, not str
# Error at 439: list indices must be integers or slices, not str
# Error at 440: list indices must be integers or slices, not str
# Error at 441: list indices must be integers or slices, not str
# Error at 442: list indices must be integers or slices, not str
# Error at 443: list indices must be integers or slices, not str
# Error at 444: list indices must be integers or slices, not str
# Error at 445: list indices must be integers or slices, not str
# Error at 446: list indices must be integers or slices, not str
# Error at 447: list indices must be integers or slices, not str
# Error at 448: list indices must be integers or slices, not str
# Error at 449: list indices must be integers or slices, not str
# Error at 450: list indices must be integers or slices, not str
# Error at 451: list indices must be integers or slices, not str
# Error at 452: list indices must be integers or slices, not str
# Error at 453: list indices must be integers or slices, not str
# Error at 454: list indices must be integers or slices, not str
# Error at 455: list indices must be integers or slices, not str
# Error at 456: list indices must be integers or slices, not str
# Error at 457: list indices must be integers or slices, not str
# Error at 458: list indices must be integers or slices, not str
# Error at 459: list indices must be integers or slices, not str
# Error at 460: list indices must be integers or slices, not str
# Error at 461: list indices must be integers or slices, not str
# Error at 462: list indices must be integers or slices, not str
# Error at 463: list indices must be integers or slices, not str
# Error at 464: list indices must be integers or slices, not str
# Error at 465: list indices must be integers or slices, not str
# Error at 466: list indices must be integers or slices, not str
# Error at 467: list indices must be integers or slices, not str
# Error at 468: list indices must be integers or slices, not str
# Error at 469: list indices must be integers or slices, not str
# Error at 470: list indices must be integers or slices, not str
# Error at 471: list indices must be integers or slices, not str
# Error at 472: list indices must be integers or slices, not str
# Error at 473: list indices must be integers or slices, not str
# Error at 474: list indices must be integers or slices, not str
# Error at 475: list indices must be integers or slices, not str
# Error at 476: list indices must be integers or slices, not str
# Error at 477: list indices must be integers or slices, not str
# Error at 478: list indices must be integers or slices, not str
# Error at 479: list indices must be integers or slices, not str
# Error at 480: list indices must be integers or slices, not str
# Error at 481: list indices must be integers or slices, not str
# Error at 482: list indices must be integers or slices, not str
# Error at 483: list indices must be integers or slices, not str
# Error at 484: list indices must be integers or slices, not str
# Error at 485: list indices must be integers or slices, not str
# Error at 486: list indices must be integers or slices, not str
# Error at 487: list indices must be integers or slices, not str
# Error at 488: list indices must be integers or slices, not str
# Error at 489: list indices must be integers or slices, not str
# Error at 490: list indices must be integers or slices, not str
# Error at 491: list indices must be integers or slices, not str
# Error at 492: list indices must be integers or slices, not str
# Error at 493: list indices must be integers or slices, not str
# Error at 494: list indices must be integers or slices, not str
# Error at 495: list indices must be integers or slices, not str
# Error at 496: list indices must be integers or slices, not str
# Error at 497: list indices must be integers or slices, not str
# Error at 498: list indices must be integers or slices, not str
# Error at 499: list indices must be integers or slices, not str

# %%
print(type(df.loc[0, "structure"]))
print(df.loc[0, "structure"])
# Out:
# <class 'pymatgen.core.structure.Structure'>
# Full Formula (Te1 Rh1 N3)
# Reduced Formula: TeRhN3
# abc   :   3.954531   3.954531   3.954531
# angles:  90.000000  90.000000  90.000000
# pbc   :       True       True       True
# Sites (5)
#   #  SP      a    b    c
# ---  ----  ---  ---  ---
#   0  Rh    0    0    0
#   1  Te    0.5  0.5  0.5
#   2  N     0.5  0    0.5
#   3  N     0.5  0.5  0
#   4  N     0    0.5  0.5

# %%
from pymatgen.core import Structure
import os
import json
from tqdm import tqdm

os.makedirs("data", exist_ok=True)
alignn_data = []

for i, row in tqdm(df.iloc[:500].iterrows(), total=500):
    try:
        struct = row["structure"]  # ← すでにStructureオブジェクト
        gap = row["gap gllbsc"]
        fname = f"data/{i}.poscar"
        struct.to(fmt="poscar", filename=fname)
        alignn_data.append({
            "id": str(i),
            "target": gap,
            "poscar": fname
        })
    except Exception as e:
        print(f"Error at {i}: {e}")

with open("atomistic.json", "w") as f:
    json.dump(alignn_data, f, indent=2)
# Out:
# 100%|██████████| 500/500 [00:02<00:00, 235.21it/s]

# %%
from alignn.train_config import TrainingConfig
import json

cfg = TrainingConfig(
    dataset="atomistic.json",
    target="target",
    id_field="id",
    n_epochs=20,
    batch_size=32,
    learning_rate=1e-3,
    classification=False,
    store_results=True,
)

with open("config.json", "w") as f:
    json.dump(cfg.as_dict(), f, indent=2)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-038cc3f59ee7> in <cell line: 0>()
# ----> 1 from alignn.train_config import TrainingConfig
#       2 import json
#       3
#       4 cfg = TrainingConfig(
#       5     dataset="atomistic.json",
#
# ModuleNotFoundError: No module named 'alignn.train_config'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
